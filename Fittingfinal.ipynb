# %% [markdown]
# <a href="https://colab.research.google.com/github/kushal-unjiya/Nth/blob/main/Fittingfinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install impedance
# Out:
# Collecting impedance
#   Downloading impedance-1.7.1-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 843.8 kB/s eta 0:00:00
# Requirement already satisfied: altair>=3.0 in /usr/local/lib/python3.10/dist-packages (from impedance) (4.2.2)
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.10/dist-packages (from impedance) (3.7.1)
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python3.10/dist-packages (from impedance) (1.25.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from impedance) (1.11.4)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair>=3.0->impedance) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair>=3.0->impedance) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair>=3.0->impedance) (4.19.2)
# Requirement already satisfied: pandas>=0.18 in /usr/local/lib/python3.10/dist-packages (from altair>=3.0->impedance) (2.0.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair>=3.0->impedance) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->impedance) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->impedance) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->impedance) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->impedance) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->impedance) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->impedance) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->impedance) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->impedance) (2.8.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair>=3.0->impedance) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair>=3.0->impedance) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair>=3.0->impedance) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair>=3.0->impedance) (0.19.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.18->altair>=3.0->impedance) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.18->altair>=3.0->impedance) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5->impedance) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair>=3.0->impedance) (2.1.5)
# Installing collected packages: impedance
# Successfully installed impedance-1.7.1

# %% [markdown]
# # 60-1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from impedance import preprocessing
from impedance.models.circuits import CustomCircuit
import seaborn as sns

# Load and process the input data
df = pd.read_csv('INPUT-DATA.csv')

# Filter and drop specific columns
# df = df[df['Ionic radius '] == 2.060000e-10]
df = df[df['Ionic radius '] == 1.820000e-10]
df = df.drop(columns=['Ionic radius '])
df = df[df['Temperature'] == 60]
df = df.drop(columns=['Temperature'])
df = df.reset_index(drop=True)

# Rename columns and adjust values
df.rename(columns={'Frequency': 'frequency'}, inplace=True)
df['Img(Z)'] = df['Img(Z)'] * -1
df.to_csv('60(1).csv', index=False)

# Load the data for fitting
frequencies, Z = preprocessing.readCSV('60(1).csv')
frequencies, Z = preprocessing.ignoreBelowX(frequencies, Z)

# Remove NaN values
mask = ~np.isnan(Z)
frequencies, Z = frequencies[mask], Z[mask]

# Check the content of frequencies and Z
print(f"frequencies: {frequencies}")
print(f"Z: {Z}")
print(f"Shape of frequencies: {frequencies.shape}")
print(f"Shape of Z: {Z.shape}")

# Define the function to fit and plot the circuit
def fit_and_plot_circuit(frequencies, Z, initial_guess, circuit_str):
    customCircuit = CustomCircuit(initial_guess=initial_guess, circuit=circuit_str)
    customCircuit.fit(frequencies, Z)
    customCircuit.plot(f_data=frequencies, Z_data=Z, kind='nyquist')
    plt.show()
    print(customCircuit)
    return customCircuit

# Initial guess for the circuit parameters
initial_guess=[4.08127359e+01,  5.10336218e+04, 1.33749422e-09, 7.20182283e-01, 0.95110848e+04, 1.37210091e-06, 9.20690396e-01]
# Circuit string
circuit_str = 'R_0-p(R_1,CPE_1)-p(R_2,CPE_2)'

# Fit and plot the circuit
customCircuit = fit_and_plot_circuit(frequencies, Z, initial_guess, circuit_str)

# Extract fitted values for plotting
Z_fit = customCircuit.predict(frequencies)

# Convert Z and Z_fit to a DataFrame
Z_df = pd.DataFrame({'Re(Z)': np.real(Z), 'Img(Z)': -np.imag(Z)})
Z_fit_df = pd.DataFrame({'Re(Z)_fit': np.real(Z_fit), 'Img(Z)_fit': -np.imag(Z_fit)})

# Save the DataFrames to CSV
Z_df.to_csv('Z60(1).csv', index=False)
Z_fit_df.to_csv('Z_fit60(1).csv', index=False)

# Load data for plotting
plot_data = pd.read_csv('Z60(1).csv')
plot_data_fit = pd.read_csv('Z_fit60(1).csv')

# Verify column names and inspect data
print(plot_data_fit.head())

# Adjust the plotting code to convert data to numpy arrays
plt.figure(figsize=(10, 6))
sns.scatterplot(x='
#  156000.-29400.j 158000.-30300.j 159000.-32000.j 161000.-33400.j
#  163000.-34900.j 165000.-36400.j 167000.-37700.j 169000.-39100.j
#  171000.-40500.j 174000.-42100.j 176000.-43600.j 178000.-44500.j
#  181000.-45900.j 184000.-46500.j 187000.-48400.j 189000.-49100.j
#  192000.-49800.j 195000.-51600.j 198000.-52400.j 201000.-52600.j
#  205000.-53300.j 207000.-55300.j 210000.-55700.j 213000.-56100.j
#  216000.-56300.j 220000.-57100.j 223000.-59300.j 226000.-59300.j
#  228000.-59500.j 232000.-59700.j 236000.-59400.j 240000.-60800.j
#  244000.-62800.j 246000.-64100.j 249000.-63800.j 252000.-63300.j
#  255000.-62700.j]
# Shape of frequencies: (181,)
# Shape of Z: (181,)
# /usr/local/lib/python3.10/dist-packages/impedance/visualization.py:39: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string ".-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(np.real(Z), -np.imag(Z), fmt, **kwargs)
# /usr/local/lib/python3.10/dist-packages/impedance/visualization.py:39: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string ".-" (-> marker='.'). The keyword argument will take precedence.
#   ax.plot(np.real(Z), -np.imag(Z), fmt, **kwargs)
# Circuit string: R_0-p(R_1,CPE_1)-p(R_2,CPE_2)
# Fit: True
#
# Initial guesses:
#     R_0 = 4.08e+01 [Ohm]
#     R_1 = 5.10e+04 [Ohm]
#   CPE_1_0 = 1.34e-09 [Ohm^-1 sec^a]
#   CPE_1_1 = 7.20e-01 []
#     R_2 = 9.51e+03 [Ohm]
#   CPE_2_0 = 1.37e-06 [Ohm^-1 sec^a]
#   CPE_2_1 = 9.21e-01 []
#
# Fit parameters:
#     R_0 = 9.80e+03  (+/- 5.10e+02) [Ohm]
#     R_1 = 1.29e+05  (+/- 2.81e+02) [Ohm]
#   CPE_1_0 = 1.95e-09  (+/- 2.08e-10) [Ohm^-1 sec^a]
#   CPE_1_1 = 7.20e-01  (+/- 1.84e-03) []
#     R_2 = 2.03e+05  (+/- 2.52e+01) [Ohm]
#   CPE_2_0 = 1.07e-06  (+/- 2.66e-08) [Ohm^-1 sec^a]
#   CPE_2_1 = 6.96e-01  (+/- 7.91e-03) []
#
#       Re(Z)_fit   Img(Z)_fit
# 0  12755.906951  5626.392844
# 1  12934.756428  5931.355074
# 2  13123.353575  6249.252284
# 3  13327.202646  6588.713240
# 4  13539.322975  6937.499545
# Circuit Type 1
#
# Circuit string: R_0-p(R_1,CPE_1)-p(R_2,CPE_2)
# Fit: True
#
# Initial guesses:
#     R_0 = 4.08e+01 [Ohm]
#     R_1 = 5.10e+04 [Ohm]
#   CPE_1_0 = 1.34e-09 [Ohm^-1 sec^a]
#   CPE_1_1 = 7.20e-01 []
#     R_2 = 9.51e+03 [Ohm]
#   CPE_2_0 = 1.37e-06 [Ohm^-1 sec^a]
#   CPE_2_1 = 9.21e-01 []
#
# Fit parameters:
#     R_0 = 9.80e+03  (+/- 5.10e+02) [Ohm]
#     R_1 = 1.29e+05  (+/- 2.81e+02) [Ohm]
#   CPE_1_0 = 1.95e-09  (+/- 2.08e-10) [Ohm^-1 sec^a]
#   CPE_1_1 = 7.20e-01  (+/- 1.84e-03) []
#     R_2 = 2.03e+05  (+/- 2.52e+01) [Ohm]
#   CPE_2_0 = 1.07e-06  (+/- 2.66e-08) [Ohm^-1 sec^a]
#   CPE_2_1 = 6.96e-01  (+/- 7.91e-03) []

# %% [markdown]
# # 60-2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from impedance import preprocessing
from impedance.models.circuits import CustomCircuit
import seaborn as sns

# Load and process the input data
df = pd.read_csv('INPUT-DATA.csv')

# Filter and drop specific columns
df = df[df['Ionic radius '] == 2.060000e-10]
# df = df[df['Ionic radius '] == 1.820000e-10]
df = df.drop(columns=['Ionic radius '])
df = df[df['Temperature'] == 60]
df = df.drop(columns=['Temperature'])
df = df.reset_index(drop=True)

# Rename columns and adjust values
df.rename(columns={'Frequency': 'frequency'}, inplace=True)
df['Img(Z)'] = df['Img(Z)'] * -1
df.to_csv('60(2).csv', index=False)

# Load the data for fitting
frequencies, Z = preprocessing.readCSV('60(2).csv')
frequencies, Z = preprocessing.ignoreBelowX(frequencies, Z)

# Remove NaN values
mask = ~np.isnan(Z)
frequencies, Z = frequencies[mask], Z[mask]

# Check the content of frequencies and Z
print(f"frequencies: {frequencies}")
print(f"Z: {Z}")
print(f"Shape of frequencies: {frequencies.shape}")
print(f"Shape of Z: {Z.shape}")

# Define the function to fit and plot the circuit
def fit_and_plot_circuit(frequencies, Z, initial_guess, circuit_str):
    customCircuit = CustomCircuit(initial_guess=initial_guess, circuit=circuit_str)
    customCircuit.fit(frequencies, Z)
    customCircuit.plot(f_data=frequencies, Z_data=Z, kind='nyquist')
    plt.show()
    print(customCircuit)
    return customCircuit

# Initial guess for the circuit parameters
initial_guess=[3.08e+03,  6.12e+04  ,2.87e-10, 9.93e-01, 3.85e+04, 5.82e-06,8.13e-01]

# Circuit string
circuit_str = 'R_0-p(R_1,CPE_1)-p(R_2,CPE_2)'

# Fit and plot the circuit
customCircuit = fit_and_plot_circuit(frequencies, Z, initial_guess, circuit_str)

# Extract fitted values for plotting
Z_fit = customCircuit.predict(frequencies)

# Convert Z and Z_fit to a DataFrame
Z_df = pd.DataFrame({'Re(Z)': np.real(Z), 'Img(Z)': -np.imag(Z)})
Z_fit_df = pd.DataFrame({'Re(Z)_fit': np.real(Z_fit), 'Img(Z)_fit': -np.imag(Z_fit)})

# Save the DataFrames to CSV
Z_df.to_csv('Z60(2).csv', index=False)
Z_fit_df.to_csv('Z_fit60(2).csv', index=False)

# Load data for plotting
plot_data = pd.read_csv('Z60(2).csv')
plot_data_fit = pd.read_csv('Z_fit60(2).csv')

# Verify column names and inspect data
print(plot_data_fit.head())

# Adjust the plotting code to convert data to numpy arrays
plt.figure(figsize=(10, 6))
sns.scatterplot(x='
# Fit parameters:
#     R_0 = 3.08e+03  (+/- 9.24e+01) [Ohm]
#     R_1 = 6.12e+04  (+/- 1.56e+02) [Ohm]
#   CPE_1_0 = 2.87e-10  (+/- 3.87e-11) [Ohm^-1 sec^a]
#   CPE_1_1 = 9.93e-01  (+/- 5.38e-04) []
#     R_2 = 3.85e+04  (+/- 9.75e+00) [Ohm]
#   CPE_2_0 = 5.80e-06  (+/- 1.08e-07) [Ohm^-1 sec^a]
#   CPE_2_1 = 8.13e-01  (+/- 7.04e-03) []
#
#      Re(Z)_fit  Img(Z)_fit
# 0  3093.168325  618.069800
# 1  3095.080777  677.234583
# 2  3097.299324  741.831956
# 3  3099.886366  812.603925
# 4  3102.928531  890.637371
# Circuit Type 1
#
# Circuit string: R_0-p(R_1,CPE_1)-p(R_2,CPE_2)
# Fit: True
#
# Initial guesses:
#     R_0 = 3.08e+03 [Ohm]
#     R_1 = 6.12e+04 [Ohm]
#   CPE_1_0 = 2.87e-10 [Ohm^-1 sec^a]
#   CPE_1_1 = 9.93e-01 []
#     R_2 = 3.85e+04 [Ohm]
#   CPE_2_0 = 5.82e-06 [Ohm^-1 sec^a]
#   CPE_2_1 = 8.13e-01 []
#
# Fit parameters:
#     R_0 = 3.08e+03  (+/- 9.24e+01) [Ohm]
#     R_1 = 6.12e+04  (+/- 1.56e+02) [Ohm]
#   CPE_1_0 = 2.87e-10  (+/- 3.87e-11) [Ohm^-1 sec^a]
#   CPE_1_1 = 9.93e-01  (+/- 5.38e-04) []
#     R_2 = 3.85e+04  (+/- 9.75e+00) [Ohm]
#   CPE_2_0 = 5.80e-06  (+/- 1.08e-07) [Ohm^-1 sec^a]
#   CPE_2_1 = 8.13e-01  (+/- 7.04e-03) []

# %% [markdown]
# # 20-1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from impedance import preprocessing
from impedance.models.circuits import CustomCircuit
import seaborn as sns

# Load and process the input data
df = pd.read_csv('INPUT-DATA.csv')

# Filter and drop specific columns
df = df[df['Ionic radius '] == 1.820000e-10]
df = df.drop(columns=['Ionic radius '])
df = df[df['Temperature'] == 20]
df = df.drop(columns=['Temperature'])
df = df.reset_index(drop=True)

# Rename columns and adjust values
df.rename(columns={'Frequency': 'frequency'}, inplace=True)
df['Img(Z)'] = df['Img(Z)'] * -1
df.to_csv('20(1).csv', index=False)

# Load the data for fitting
frequencies, Z = preprocessing.readCSV('20(1).csv')
frequencies, Z = preprocessing.ignoreBelowX(frequencies, Z)

# Remove NaN values
mask = ~np.isnan(Z)
frequencies, Z = frequencies[mask], Z[mask]

# Check the content of frequencies and Z
print(f"frequencies: {frequencies}")
print(f"Z: {Z}")
print(f"Shape of frequencies: {frequencies.shape}")
print(f"Shape of Z: {Z.shape}")

# Define the function to fit and plot the circuit
def fit_and_plot_circuit(frequencies, Z, initial_guess, circuit_str):
    customCircuit = CustomCircuit(initial_guess=initial_guess, circuit=circuit_str)
    customCircuit.fit(frequencies, Z)
    customCircuit.plot(f_data=frequencies, Z_data=Z, kind='nyquist')
    plt.show()
    print(customCircuit)
    return customCircuit

# Initial guess for the circuit parameters
initial_guess=[2.50e+04, 2.03e+05 ,2.25e-10 , 9.88e-01,2.83e+05 , 8.86e-07, 7.79e-01]

# Circuit string
circuit_str = 'R_0-p(R_1,CPE_1)-p(R_2,CPE_2)'

# Fit and plot the circuit
customCircuit = fit_and_plot_circuit(frequencies, Z, initial_guess, circuit_str)

# Extract fitted values for plotting
Z_fit = customCircuit.predict(frequencies)

# Convert Z and Z_fit to a DataFrame
Z_df = pd.DataFrame({'Re(Z)': np.real(Z), 'Img(Z)': -np.imag(Z)})
Z_fit_df = pd.DataFrame({'Re(Z)_fit': np.real(Z_fit), 'Img(Z)_fit': -np.imag(Z_fit)})

# Save the DataFrames to CSV
Z_df.to_csv('Z20(1).csv', index=False)
Z_fit_df.to_csv('Z_fit20(1).csv', index=False)

# Load data for plotting
plot_data = pd.read_csv('Z20(1).csv')
plot_data_fit = pd.read_csv('Z_fit20(1).csv')

# Verify column names and inspect data
print(plot_data_fit.head())

# Adjust the plotting code to convert data to numpy arrays
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Re(Z)', y='Img(Z)', data=plot_data, label='Data', color='blue')
sns.scatterplot(x=plot_data_fit['Re(Z)_fit'].values, y=plot_data_fit['Img(Z)_fit'].values, label='Fit', color='red')
plt.xlabel('Re(Z) [Ohm]')
plt.ylabel('-Imag(Z) [Ohm]')
plt.title('Nyquist Plot')
plt.legend()
plt.show()

print('Circuit Type', 1)
print(customCircuit)
# Out:
# frequencies: [1.00e+06 9.26e+05 8.58e+05 7.94e+05 7.36e+05 6.81e+05 6.31e+05 5.84e+05
#  5.41e+05 5.01e+05 4.64e+05 4.30e+05 3.98e+05 3.69e+05 3.41e+05 3.16e+05
#  2.93e+05 2.71e+05 2.51e+05 2.33e+05 2.15e+05 2.00e+05 1.85e+05 1.71e+05
#  1.58e+05 1.47e+05 1.36e+05 1.26e+05 1.17e+05 1.08e+05 1.00e+05 9.26e+04
#  8.58e+04 7.94e+04 7.36e+04 6.81e+04 6.31e+04 5.84e+04 5.41e+04 5.01e+04
#  4.64e+04 4.30e+04 3.98e+04 3.69e+04 3.41e+04 3.16e+04 2.93e+04 2.71e+04
#  2.51e+04 2.33e+04 2.15e+04 1.99e+04 1.85e+04 1.71e+04 1.58e+04 1.47e+04
#  1.36e+04 1.26e+04 1.17e+04 1.08e+04 1.00e+04 9.26e+03 8.57e+03 7.94e+03
#  7.35e+03 6.81e+03 6.31e+03 5.84e+03 5.41e+03 5.01e+03 4.64e+03 4.30e+03
#  3.98e+03 3.69e+03 3.42e+03 3.16e+03 2.93e+03 2.71e+03 2.51e+03 2.33e+03
#  2.15e+03 2.00e+03 1.85e+03 1.71e+03 1.58e+03 1.47e+03 1.36e+03 1.26e+03
#  1.17e+03 1.08e+03 1.00e+03 9.26e+02 8.58e+02 7.94e+02 7.36e+02 6.81e+02
#  6.31e+02 5.84e+02 5.41e+02 5.01e+02 4.64e+02 4.30e+02 3.98e+02 3.69e+02
#  3.41e+02 3.16e+02 2.93e+02 2.71e+02 2.51e+02 2.33e+02 2.15e+02 2.00e+02
#  207000. -11200.j 205000. -13200.j 205000. -15400.j 204000. -17700.j
#  204000. -20600.j 205000. -22900.j 204000. -26100.j 205000. -28300.j
#  205000. -31500.j 206000. -34500.j 206000. -38100.j 208000. -41700.j
#  209000. -44900.j 211000. -48500.j 212000. -51900.j 214000. -55500.j
#  217000. -59600.j 220000. -62500.j 222000. -66800.j 225000. -70800.j
#  229000. -74500.j 233000. -78100.j 237000. -81800.j 240000. -85400.j
#  245000. -89400.j 248000. -93000.j 253000. -95900.j 259000. -98900.j
#  264000.-102000.j 270000.-106000.j 274000.-109000.j 280000.-110000.j
#  285000.-111000.j 292000.-114000.j 299000.-116000.j 303000.-119000.j
#  308000.-121000.j 312000.-121000.j 318000.-120000.j 324000.-119000.j
#  331000.-120000.j]
# Shape of frequencies: (161,)
# Shape of Z: (161,)
# /usr/local/lib/python3.10/dist-packages/impedance/visualization.py:39: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string ".-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(np.real(Z), -np.imag(Z), fmt, **kwargs)
# /usr/local/lib/python3.10/dist-packages/impedance/visualization.py:39: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string ".-" (-> marker='.'). The keyword argument will take precedence.
#   ax.plot(np.real(Z), -np.imag(Z), fmt, **kwargs)
# Circuit string: R_0-p(R_1,CPE_1)-p(R_2,CPE_2)
# Fit: True
#
# Initial guesses:
#     R_0 = 2.50e+04 [Ohm]
#     R_1 = 2.03e+05 [Ohm]
#   CPE_1_0 = 2.25e-10 [Ohm^-1 sec^a]
#   CPE_1_1 = 9.88e-01 []
#     R_2 = 2.83e+05 [Ohm]
#   CPE_2_0 = 8.86e-07 [Ohm^-1 sec^a]
#   CPE_2_1 = 7.79e-01 []
#
# Fit parameters:
#     R_0 = 2.50e+04  (+/- 2.32e+03) [Ohm]
#     R_1 = 2.03e+05  (+/- 3.46e+02) [Ohm]
#   CPE_1_0 = 2.25e-10  (+/- 2.97e-10) [Ohm^-1 sec^a]
#   CPE_1_1 = 9.88e-01  (+/- 4.17e-03) []
#     R_2 = 2.83e+05  (+/- 3.70e+01) [Ohm]
#   CPE_2_0 = 8.86e-07  (+/- 7.26e-08) [Ohm^-1 sec^a]
#   CPE_2_1 = 7.79e-01  (+/- 2.70e-02) []
#
#       Re(Z)_fit   Img(Z)_fit
# 0  25021.616199   858.593265
# 1  25023.593861   926.244971
# 2  25025.757383   998.625307
# 3  25028.186499  1077.990679
# 4  25030.814792  1161.750879
# Circuit Type 1
#
# Circuit string: R_0-p(R_1,CPE_1)-p(R_2,CPE_2)
# Fit: True
#
# Initial guesses:
#     R_0 = 2.50e+04 [Ohm]
#     R_1 = 2.03e+05 [Ohm]
#   CPE_1_0 = 2.25e-10 [Ohm^-1 sec^a]
#   CPE_1_1 = 9.88e-01 []
#     R_2 = 2.83e+05 [Ohm]
#   CPE_2_0 = 8.86e-07 [Ohm^-1 sec^a]
#   CPE_2_1 = 7.79e-01 []
#
# Fit parameters:
#     R_0 = 2.50e+04  (+/- 2.32e+03) [Ohm]
#     R_1 = 2.03e+05  (+/- 3.46e+02) [Ohm]
#   CPE_1_0 = 2.25e-10  (+/- 2.97e-10) [Ohm^-1 sec^a]
#   CPE_1_1 = 9.88e-01  (+/- 4.17e-03) []
#     R_2 = 2.83e+05  (+/- 3.70e+01) [Ohm]
#   CPE_2_0 = 8.86e-07  (+/- 7.26e-08) [Ohm^-1 sec^a]
#   CPE_2_1 = 7.79e-01  (+/- 2.70e-02) []

# %% [markdown]
# # 20-2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from impedance import preprocessing
from impedance.models.circuits import CustomCircuit
import seaborn as sns

# Load and process the input data
df = pd.read_csv('INPUT-DATA.csv')

# Filter and drop specific columns
df = df[df['Ionic radius '] == 2.060000e-10]
df = df.drop(columns=['Ionic radius '])
df = df[df['Temperature'] == 20]
df = df.drop(columns=['Temperature'])
df = df.reset_index(drop=True)

# Rename columns and adjust values
df.rename(columns={'Frequency': 'frequency'}, inplace=True)
df['Img(Z)'] = df['Img(Z)'] * -1
df.to_csv('20(2).csv', index=False)

# Load the data for fitting
frequencies, Z = preprocessing.readCSV('20(2).csv')
frequencies, Z = preprocessing.ignoreBelowX(frequencies, Z)

# Remove NaN values
mask = ~np.isnan(Z)
frequencies, Z = frequencies[mask], Z[mask]

# Check the content of frequencies and Z
print(f"frequencies: {frequencies}")
print(f"Z: {Z}")
print(f"Shape of frequencies: {frequencies.shape}")
print(f"Shape of Z: {Z.shape}")

# Define the function to fit and plot the circuit
def fit_and_plot_circuit(frequencies, Z, initial_guess, circuit_str):
    customCircuit = CustomCircuit(initial_guess=initial_guess, circuit=circuit_str)
    customCircuit.fit(frequencies, Z)
    customCircuit.plot(f_data=frequencies, Z_data=Z, kind='nyquist')
    plt.show()
    print(customCircuit)
    return customCircuit

# Initial guess for the circuit parameters
initial_guess = [5.41e+01 , 8.68e+04, 5.65e-10,8.94e-01 ,3.33e+04, 2.10e-06, 9.36e-01]

# Circuit string
circuit_str = 'R_0-p(R_1,CPE_1)-p(R_2,CPE_2)'

# Fit and plot the circuit
customCircuit = fit_and_plot_circuit(frequencies, Z, initial_guess, circuit_str)

# Extract fitted values for plotting
Z_fit = customCircuit.predict(frequencies)

# Convert Z and Z_fit to a DataFrame
Z_df = pd.DataFrame({'Re(Z)': np.real(Z), 'Img(Z)': -np.imag(Z)})
Z_fit_df = pd.DataFrame({'Re(Z)_fit': np.real(Z_fit), 'Img(Z)_fit': -np.imag(Z_fit)})

# Save the DataFrames to CSV
Z_df.to_csv('Z20(2).csv', index=False)
Z_fit_df.to_csv('Z_fit20(2).csv', index=False)

# Load data for plotting
plot_data = pd.read_csv('Z20(2).csv')
plot_data_fit = pd.read_csv('Z_fit20(2).csv')

# Verify column names and inspect data
print(plot_data_fit.head())

# Adjust the plotting code to convert data to numpy arrays
plt.figure(figsize=(10, 6))
sns.scatterplot(x='
#   CPE_2_1 = 9.36e-01 []
#
# Fit parameters:
#     R_0 = 5.41e+01  (+/- 4.77e+02) [Ohm]
#     R_1 = 8.68e+04  (+/- 6.89e+02) [Ohm]
#   CPE_1_0 = 5.65e-10  (+/- 1.35e-10) [Ohm^-1 sec^a]
#   CPE_1_1 = 8.94e-01  (+/- 2.03e-03) []
#     R_2 = 3.33e+04  (+/- 1.39e+02) [Ohm]
#   CPE_2_0 = 2.10e-06  (+/- 1.76e-07) [Ohm^-1 sec^a]
#   CPE_2_1 = 9.36e-01  (+/- 2.34e-02) []
#
#     Re(Z)_fit   Img(Z)_fit
# 0  323.125883  1451.503656
# 1  348.400527  1575.255824
# 2  376.133424  1709.006050
# 3  406.697464  1854.048531
# 4  440.632156  2012.321639
# Circuit Type 1
#
# Circuit string: R_0-p(R_1,CPE_1)-p(R_2,CPE_2)
# Fit: True
#
# Initial guesses:
#     R_0 = 5.41e+01 [Ohm]
#     R_1 = 8.68e+04 [Ohm]
#   CPE_1_0 = 5.65e-10 [Ohm^-1 sec^a]
#   CPE_1_1 = 8.94e-01 []
#     R_2 = 3.33e+04 [Ohm]
#   CPE_2_0 = 2.10e-06 [Ohm^-1 sec^a]
#   CPE_2_1 = 9.36e-01 []
#
# Fit parameters:
#     R_0 = 5.41e+01  (+/- 4.77e+02) [Ohm]
#     R_1 = 8.68e+04  (+/- 6.89e+02) [Ohm]
#   CPE_1_0 = 5.65e-10  (+/- 1.35e-10) [Ohm^-1 sec^a]
#   CPE_1_1 = 8.94e-01  (+/- 2.03e-03) []
#     R_2 = 3.33e+04  (+/- 1.39e+02) [Ohm]
#   CPE_2_0 = 2.10e-06  (+/- 1.76e-07) [Ohm^-1 sec^a]
#   CPE_2_1 = 9.36e-01  (+/- 2.34e-02) []

# %% [markdown]
# # **-5**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from impedance import preprocessing
from impedance.models.circuits import CustomCircuit
import seaborn as sns

# Load and process the input data
df = pd.read_csv('INPUT-DATA.csv')

# Filter and drop specific columns
df = df[df['Ionic radius '] == 2.060000e-10]
# df = df[df['Ionic radius '] == 1.820000e-10]
df = df.drop(columns=['Ionic radius '])
df = df[df['Temperature'] == -5]
df = df.drop(columns=['Temperature'])
df = df.reset_index(drop=True)

# Rename columns and adjust values
df.rename(columns={'Frequency': 'frequency'}, inplace=True)
df['Img(Z)'] = df['Img(Z)'] * -1
df.to_csv('-5.csv', index=False)

# Load the data for fitting
frequencies, Z = preprocessing.readCSV('-5.csv')
frequencies, Z = preprocessing.ignoreBelowX(frequencies, Z)

# Remove NaN values
mask = ~np.isnan(Z)
frequencies, Z = frequencies[mask], Z[mask]

# Check the content of frequencies and Z
print(f"frequencies: {frequencies}")
print(f"Z: {Z}")
print(f"Shape of frequencies: {frequencies.shape}")
print(f"Shape of Z: {Z.shape}")

# Define the function to fit and plot the circuit
def fit_and_plot_circuit(frequencies, Z, initial_guess, circuit_str):
    customCircuit = CustomCircuit(initial_guess=initial_guess, circuit=circuit_str)
    customCircuit.fit(frequencies, Z)
    customCircuit.plot(f_data=frequencies, Z_data=Z, kind='nyquist')
    plt.show()
    print(customCircuit)
    return customCircuit

# Initial guess for the circuit parameters
initial_guess=[20.02735900e+01, 13.5748999e+03, 16.07494220e-15, 8.01192283e-01, 3.80319480e-00, 8.37210091e-06, 9.00690396e-01 ]
circuit_str = 'R_0-p(R_1,CPE_1)-p(R_2,CPE_2)'

# Fit and plot the circuit
customCircuit = fit_and_plot_circuit(frequencies, Z, initial_guess, circuit_str)

# Extract fitted values for plotting
Z_fit = customCircuit.predict(frequencies)

# Convert Z and Z_fit to a DataFrame
Z_df = pd.DataFrame({'Re(Z)': np.real(Z), 'Img(Z)': -np.imag(Z)})
Z_fit_df = pd.DataFrame({'Re(Z)_fit': np.real(Z_fit), 'Img(Z)_fit': -np.imag(Z_fit)})

# Save the DataFrames to CSV
Z_df.to_csv('Z-5.csv', index=False)
Z_fit_df.to_csv('Z_fit-5.csv', index=False)

# Load data for plotting
plot_data = pd.read_csv('Z-5.csv')
plot_data_fit = pd.read_csv('Z_fit-5.csv')

# Verify column names and inspect data
print(plot_data_fit.head())

# Adjust the plotting code to convert data to numpy arrays
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Re(Z)', y='Img(Z)', data=plot_data, label='Data', color='blue')
sns.scatterplot(x=plot_data_fit['Re(Z)_fit'].values, y=plot_data_fit['Img(Z)_fit'].values, label='Fit', color='red')
plt.xlabel('Re(Z) [Ohm]')
plt.ylabel('-Imag(Z) [Ohm]')
plt.title('Nyquist Plot')
plt.legend()
plt.show()

print('Circuit Type', 1)
print(customCircuit)
# Out:
# frequencies: [1.00e+06 9.12e+05 8.32e+05 7.59e+05 6.92e+05 6.31e+05 5.75e+05 5.25e+05
#  4.79e+05 4.37e+05 3.98e+05 3.63e+05 3.31e+05 3.02e+05 2.75e+05 2.51e+05
#  2.29e+05 2.09e+05 1.91e+05 1.74e+05 1.58e+05 1.45e+05 1.32e+05 1.20e+05
#  1.10e+05 1.00e+05 9.12e+04 8.32e+04 7.59e+04 6.92e+04 6.31e+04 5.75e+04
#  5.25e+04 4.79e+04 4.37e+04 3.98e+04 3.63e+04 3.31e+04 3.02e+04 2.75e+04
#  2.51e+04 2.29e+04 2.09e+04 1.91e+04 1.74e+04 1.58e+04 1.45e+04 1.32e+04
#  1.20e+04 1.10e+04 1.00e+04 9.12e+03 8.32e+03 7.59e+03 6.92e+03 6.31e+03
#  5.75e+03 5.25e+03 4.79e+03 4.37e+03 3.98e+03 3.63e+03 3.31e+03 3.02e+03
#  2.75e+03 2.51e+03 2.29e+03 2.09e+03 1.91e+03 1.74e+03 1.58e+03 1.45e+03
#  1.32e+03 1.20e+03 1.10e+03 1.00e+03 9.12e+02 8.32e+02 7.59e+02 6.92e+02
#  6.31e+02 5.75e+02 5.25e+02 4.79e+02 4.37e+02 3.98e+02 3.63e+02 3.31e+02
#  3.02e+02 2.75e+02 2.51e+02 2.29e+02 2.09e+02 1.91e+02 1.74e+02 1.58e+02
#  1.45e+02 1.32e+02 1.20e+02 1.10e+02 1.00e+02 9.12e+01 8.32e+01 7.59e+01
#  132000.-24400.j 132000.-23300.j 134000.-23900.j 135000.-24400.j
#  137000.-25100.j 139000.-25600.j 140000.-25900.j 142000.-25300.j
#  144000.-25800.j 145000.-26000.j 147000.-26300.j 149000.-26700.j
#  151000.-27100.j 153000.-27500.j 154000.-26900.j 156000.-27600.j
#  157000.-27300.j 159000.-27700.j 161000.-27600.j 162000.-27900.j
#  164000.-27900.j 166000.-27700.j 167000.-28200.j 169000.-27900.j
#  171000.-28200.j 173000.-28300.j 175000.-28400.j 177000.-29100.j
#  179000.-28300.j 180000.-28100.j 183000.-29300.j]
# Shape of frequencies: (151,)
# Shape of Z: (151,)
# /usr/local/lib/python3.10/dist-packages/impedance/visualization.py:39: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string ".-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(np.real(Z), -np.imag(Z), fmt, **kwargs)
# /usr/local/lib/python3.10/dist-packages/impedance/visualization.py:39: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string ".-" (-> marker='.'). The keyword argument will take precedence.
#   ax.plot(np.real(Z), -np.imag(Z), fmt, **kwargs)
# Circuit string: R_0-p(R_1,CPE_1)-p(R_2,CPE_2)
# Fit: True
#
# Initial guesses:
#     R_0 = 2.00e+02 [Ohm]
#     R_1 = 1.36e+04 [Ohm]
#   CPE_1_0 = 1.61e-14 [Ohm^-1 sec^a]
#   CPE_1_1 = 8.01e-01 []
#     R_2 = 3.80e+00 [Ohm]
#   CPE_2_0 = 8.37e-06 [Ohm^-1 sec^a]
#   CPE_2_1 = 9.01e-01 []
#
# Fit parameters:
#     R_0 = 8.87e+03  (+/- 3.13e+02) [Ohm]
#     R_1 = 9.95e+04  (+/- 2.87e+01) [Ohm]
#   CPE_1_0 = 2.03e-10  (+/- 6.52e-11) [Ohm^-1 sec^a]
#   CPE_1_1 = 9.85e-01  (+/- 9.37e-04) []
#     R_2 = 1.16e+05  (+/- 9.44e+00) [Ohm]
#   CPE_2_0 = 1.92e-06  (+/- 4.32e-08) [Ohm^-1 sec^a]
#   CPE_2_1 = 5.76e-01  (+/- 5.67e-03) []
#
#      Re(Z)_fit   Img(Z)_fit
# 0  8941.374578  1039.800127
# 1  8947.690939  1136.461414
# 2  8954.698816  1241.807605
# 3  8962.522903  1357.019064
# 4  8971.340661  1483.830065
# Circuit Type 1
#
# Circuit string: R_0-p(R_1,CPE_1)-p(R_2,CPE_2)
# Fit: True
#
# Initial guesses:
#     R_0 = 2.00e+02 [Ohm]
#     R_1 = 1.36e+04 [Ohm]
#   CPE_1_0 = 1.61e-14 [Ohm^-1 sec^a]
#   CPE_1_1 = 8.01e-01 []
#     R_2 = 3.80e+00 [Ohm]
#   CPE_2_0 = 8.37e-06 [Ohm^-1 sec^a]
#   CPE_2_1 = 9.01e-01 []
#
# Fit parameters:
#     R_0 = 8.87e+03  (+/- 3.13e+02) [Ohm]
#     R_1 = 9.95e+04  (+/- 2.87e+01) [Ohm]
#   CPE_1_0 = 2.03e-10  (+/- 6.52e-11) [Ohm^-1 sec^a]
#   CPE_1_1 = 9.85e-01  (+/- 9.37e-04) []
#     R_2 = 1.16e+05  (+/- 9.44e+00) [Ohm]
#   CPE_2_0 = 1.92e-06  (+/- 4.32e-08) [Ohm^-1 sec^a]
#   CPE_2_1 = 5.76e-01  (+/- 5.67e-03) []

# %% [markdown]
# # 25

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from impedance import preprocessing
from impedance.models.circuits import CustomCircuit
import seaborn as sns

# Load and process the input data
df = pd.read_csv('INPUT-DATA.csv')

# Filter and drop specific columns
df = df[df['Ionic radius '] == 2.060000e-10]
# df = df[df['Ionic radius '] == 1.820000e-10]
df = df.drop(columns=['Ionic radius '])
df = df[df['Temperature'] == 25]
df = df.drop(columns=['Temperature'])
df = df.reset_index(drop=True)

# Rename columns and adjust values
df.rename(columns={'Frequency': 'frequency'}, inplace=True)
df['Img(Z)'] = df['Img(Z)'] * -1
df.to_csv('25.csv', index=False)

# Load the data for fitting
frequencies, Z = preprocessing.readCSV('25.csv')
frequencies, Z = preprocessing.ignoreBelowX(frequencies, Z)

# Remove NaN values
mask = ~np.isnan(Z)
frequencies, Z = frequencies[mask], Z[mask]

# Check the content of frequencies and Z
print(f"frequencies: {frequencies}")
print(f"Z: {Z}")
print(f"Shape of frequencies: {frequencies.shape}")
print(f"Shape of Z: {Z.shape}")

# Define the function to fit and plot the circuit
def fit_and_plot_circuit(frequencies, Z, initial_guess, circuit_str):
    customCircuit = CustomCircuit(initial_guess=initial_guess, circuit=circuit_str)
    customCircuit.fit(frequencies, Z)
    customCircuit.plot(f_data=frequencies, Z_data=Z, kind='nyquist')
    plt.show()
    print(customCircuit)
    return customCircuit

# Initial guess for the circuit parameters
initial_guess=[20.15735900e+01, 13.4940999e+03, 19.61994920e-15, 8.13190283e-01, 3.79329481e-00, 8.01916291e-06, 9.00890496e-01 ]
# Circuit string
circuit_str = 'R_0-p(R_1,CPE_1)-p(R_2,CPE_2)'

# Fit and plot the circuit
customCircuit = fit_and_plot_circuit(frequencies, Z, initial_guess, circuit_str)

# Extract fitted values for plotting
Z_fit = customCircuit.predict(frequencies)

# Convert Z and Z_fit to a DataFrame
Z_df = pd.DataFrame({'Re(Z)': np.real(Z), 'Img(Z)': -np.imag(Z)})
Z_fit_df = pd.DataFrame({'Re(Z)_fit': np.real(Z_fit), 'Img(Z)_fit': -np.imag(Z_fit)})

# Save the DataFrames to CSV
Z_df.to_csv('Z25.csv', index=False)
Z_fit_df.to_csv('Z_fit25.csv', index=False)

# Load data for plotting
plot_data = pd.read_csv('Z25.csv')
plot_data_fit = pd.read_csv('Z_fit25.csv')

# Verify column names and inspect data
print(plot_data_fit.head())

# Adjust the plotting code to convert data to numpy arrays
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Re(Z)', y='Img(Z)', data=plot_data, label='Data', color='blue')
sns.scatterplot(x=plot_data_fit['Re(Z)_fit'].values, y=plot_data_fit['Img(Z)_fit'].values, label='Fit', color='red')
plt.xlabel('Re(Z) [Ohm]')
plt.ylabel('-Imag(Z) [Ohm]')
plt.title('Nyquist Plot')
plt.legend()
plt.show()

print('Circuit Type', 1)
print(customCircuit)
# Out:
#   22500.-31400.j  25000.-32600.j  29600.-35500.j  32600.-36700.j
#   36000.-37700.j  39500.-38300.j  43200.-38600.j  46800.-38500.j
#   50400.-38100.j  54000.-37700.j  57300.-36500.j  60400.-35300.j
#   63400.-33800.j  66200.-32300.j  68700.-30500.j  70600.-28700.j
#   72800.-26700.j  74400.-24700.j  75800.-22800.j  76800.-20900.j
#   77800.-19100.j  78600.-17500.j  79400.-15700.j  80100.-14500.j
#   80400.-13200.j  80700.-11900.j  81000.-10500.j  81300. -9490.j
#   81400. -8440.j  81600. -7420.j  81700. -6660.j  81800. -5890.j
#   81500. -5140.j  81700. -4630.j  81700. -4090.j  81400. -3500.j
#   81300. -3190.j  81300. -2630.j  81000. -2260.j  80900. -1860.j
#   80700. -1730.j  80900. -1570.j  80800. -1570.j  80700. -1110.j
#   80600. -1030.j  80700. -1170.j  80500.  -752.j  80500.  -960.j
#   80300.  -912.j  80200.  -943.j  80400.  -978.j  80000.  -920.j
#   79900. -1060.j  79900. -1180.j  80000. -1310.j  80000. -1640.j
#   80000. -1800.j  80000. -2120.j  80100. -2250.j  80000. -2380.j
#   80200. -2430.j  80400. -2990.j  80600. -3040.j  79800. -2080.j
#   80600. -3850.j  80900. -4010.j  81100. -4360.j  81300. -4470.j
#   81600. -5060.j  81700. -5520.j  82200. -5730.j  82300. -6220.j
#   82800. -6540.j  83100. -7030.j  83400. -7380.j  84100. -7830.j
#   84800. -7960.j  85100. -8530.j  85400. -8720.j  85900. -9310.j
#   86700. -9620.j  87100.-10000.j  87600.-10400.j  88400.-10700.j
#   89300.-11100.j  89900.-11100.j  90200.-11500.j  91300.-12000.j
#   92000.-12300.j  92900.-12400.j  93600.-12900.j  94500.-13000.j
#   95300.-13500.j  96400.-13600.j  97000.-13900.j  97800.-14100.j
#   98800.-14300.j  99700.-14600.j 101000.-15000.j 102000.-15000.j
#  103000.-15200.j 104000.-15500.j 105000.-15700.j 106000.-15800.j
#  106000.-16100.j 108000.-16300.j 109000.-16600.j]
# Shape of frequencies: (151,)
# Shape of Z: (151,)
# /usr/local/lib/python3.10/dist-packages/impedance/visualization.py:39: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string ".-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(np.real(Z), -np.imag(Z), fmt, **kwargs)
# /usr/local/lib/python3.10/dist-packages/impedance/visualization.py:39: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string ".-" (-> marker='.'). The keyword argument will take precedence.
#   ax.plot(np.real(Z), -np.imag(Z), fmt, **kwargs)
# Circuit string: R_0-p(R_1,CPE_1)-p(R_2,CPE_2)
# Fit: True
#
# Initial guesses:
#     R_0 = 2.02e+02 [Ohm]
#     R_1 = 1.35e+04 [Ohm]
#   CPE_1_0 = 1.96e-14 [Ohm^-1 sec^a]
#   CPE_1_1 = 8.13e-01 []
#     R_2 = 3.79e+00 [Ohm]
#   CPE_2_0 = 8.02e-06 [Ohm^-1 sec^a]
#   CPE_2_1 = 9.01e-01 []
#
# Fit parameters:
#     R_0 = 6.13e+03  (+/- 3.90e+02) [Ohm]
#     R_1 = 7.64e+04  (+/- 7.39e+02) [Ohm]
#   CPE_1_0 = 2.12e-10  (+/- 1.41e-10) [Ohm^-1 sec^a]
#   CPE_1_1 = 9.91e-01  (+/- 1.82e-03) []
#     R_2 = 4.50e+04  (+/- 5.08e+01) [Ohm]
#   CPE_2_0 = 6.25e-06  (+/- 4.44e-07) [Ohm^-1 sec^a]
#   CPE_2_1 = 7.44e-01  (+/- 2.86e-02) []
#
#      Re(Z)_fit   Img(Z)_fit
# 0  6151.113935   864.515131
# 1  6154.278719   947.058069
# 2  6157.935921  1037.158565
# 3  6162.184645  1135.847248
# 4  6167.162657  1244.634444
# Circuit Type 1
#
# Circuit string: R_0-p(R_1,CPE_1)-p(R_2,CPE_2)
# Fit: True
#
# Initial guesses:
#     R_0 = 2.02e+02 [Ohm]
#     R_1 = 1.35e+04 [Ohm]
#   CPE_1_0 = 1.96e-14 [Ohm^-1 sec^a]
#   CPE_1_1 = 8.13e-01 []
#     R_2 = 3.79e+00 [Ohm]
#   CPE_2_0 = 8.02e-06 [Ohm^-1 sec^a]
#   CPE_2_1 = 9.01e-01 []
#
# Fit parameters:
#     R_0 = 6.13e+03  (+/- 3.90e+02) [Ohm]
#     R_1 = 7.64e+04  (+/- 7.39e+02) [Ohm]
#   CPE_1_0 = 2.12e-10  (+/- 1.41e-10) [Ohm^-1 sec^a]
#   CPE_1_1 = 9.91e-01  (+/- 1.82e-03) []
#     R_2 = 4.50e+04  (+/- 5.08e+01) [Ohm]
#   CPE_2_0 = 6.25e-06  (+/- 4.44e-07) [Ohm^-1 sec^a]
#   CPE_2_1 = 7.44e-01  (+/- 2.86e-02) []

# %% [markdown]
# # **55**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from impedance import preprocessing
from impedance.models.circuits import CustomCircuit
import seaborn as sns

# Load and process the input data
df = pd.read_csv('INPUT-DATA.csv')

# Filter and drop specific columns
df = df[df['Ionic radius '] == 2.060000e-10]
# df = df[df['Ionic radius '] == 1.820000e-10]
df = df.drop(columns=['Ionic radius '])
df = df[df['Temperature'] == 55]
df = df.drop(columns=['Temperature'])
df = df.reset_index(drop=True)

# Rename columns and adjust values
df.rename(columns={'Frequency': 'frequency'}, inplace=True)
df['Img(Z)'] = df['Img(Z)'] * -1
df.to_csv('25.csv', index=False)

# Load the data for fitting
frequencies, Z = preprocessing.readCSV('25.csv')
frequencies, Z = preprocessing.ignoreBelowX(frequencies, Z)

# Remove NaN values
mask = ~np.isnan(Z)
frequencies, Z = frequencies[mask], Z[mask]

# Check the content of frequencies and Z
print(f"frequencies: {frequencies}")
print(f"Z: {Z}")
print(f"Shape of frequencies: {frequencies.shape}")
print(f"Shape of Z: {Z.shape}")

# Define the function to fit and plot the circuit
def fit_and_plot_circuit(frequencies, Z, initial_guess, circuit_str):
    customCircuit = CustomCircuit(initial_guess=initial_guess, circuit=circuit_str)
    customCircuit.fit(frequencies, Z)
    customCircuit.plot(f_data=frequencies, Z_data=Z, kind='nyquist')
    plt.show()
    print(customCircuit)
    return customCircuit

# Initial guess for the circuit parameters
initial_guess=[3.29e+02,  6.54e+04 , 5.47e-10 , 9.26e-01,9.23e+04 , 9.87e-06, 2.94e-01  ]
# Circuit string
circuit_str = 'R_0-p(R_1,CPE_1)-p(R_2,CPE_2)'
# Fit and plot the circuit
customCircuit = fit_and_plot_circuit(frequencies, Z, initial_guess, circuit_str)

# Extract fitted values for plotting
Z_fit = customCircuit.predict(frequencies)

# Convert Z and Z_fit to a DataFrame
Z_df = pd.DataFrame({'Re(Z)': np.real(Z), 'Img(Z)': -np.imag(Z)})
Z_fit_df = pd.DataFrame({'Re(Z)_fit': np.real(Z_fit), 'Img(Z)_fit': -np.imag(Z_fit)})

# Save the DataFrames to CSV
Z_df.to_csv('Z25.csv', index=False)
Z_fit_df.to_csv('Z_fit25.csv', index=False)

# Load data for plotting
plot_data = pd.read_csv('Z25.csv')
plot_data_fit = pd.read_csv('Z_fit25.csv')

# Verify column names and inspect data
print(plot_data_fit.head())

# Adjust the plotting code to convert data to numpy arrays
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Re(Z)', y='Img(Z)', data=plot_data, label='Data', color='blue')
sns.scatterplot(x=plot_data_fit['Re(Z)_fit'].values, y=plot_data_fit['Img(Z)_fit'].values, label='Fit', color='red')
plt.xlabel('Re(Z) [Ohm]')
plt.ylabel('-Imag(Z) [Ohm]')
plt.title('Nyquist Plot')
plt.legend()
plt.show()

print('Circuit Type', 1)
print(customCircuit)
# Out:
# frequencies: [1.00e+06 9.12e+05 8.32e+05 7.59e+05 6.92e+05 6.31e+05 5.75e+05 5.25e+05
#  4.79e+05 4.37e+05 3.98e+05 3.63e+05 3.31e+05 3.02e+05 2.75e+05 2.51e+05
#  2.29e+05 2.09e+05 1.91e+05 1.74e+05 1.58e+05 1.45e+05 1.32e+05 1.20e+05
#  1.10e+05 1.00e+05 9.12e+04 8.32e+04 7.59e+04 6.92e+04 6.31e+04 5.75e+04
#  5.25e+04 4.79e+04 4.37e+04 3.98e+04 3.63e+04 3.31e+04 3.02e+04 2.75e+04
#  2.51e+04 2.29e+04 2.09e+04 1.91e+04 1.74e+04 1.58e+04 1.45e+04 1.32e+04
#  1.20e+04 1.10e+04 1.00e+04 9.12e+03 8.32e+03 7.59e+03 6.92e+03 6.31e+03
#  5.75e+03 5.25e+03 4.79e+03 4.37e+03 3.98e+03 3.63e+03 3.31e+03 3.02e+03
#  2.75e+03 2.51e+03 2.29e+03 2.09e+03 1.91e+03 1.74e+03 1.58e+03 1.45e+03
#  1.32e+03 1.20e+03 1.10e+03 1.00e+03 9.12e+02 8.32e+02 7.59e+02 6.92e+02
#  6.31e+02 5.75e+02 5.25e+02 4.79e+02 4.37e+02 3.98e+02 3.63e+02 3.31e+02
#  3.02e+02 2.75e+02 2.51e+02 2.29e+02 2.09e+02 1.91e+02 1.74e+02 1.58e+02
#  1.45e+02 1.32e+02 1.20e+02 1.10e+02 1.00e+02 9.12e+01 8.32e+01 7.59e+01
#  6.92e+01 6.31e+01 5.75e+01 5.25e+01 4.79e+01 4.37e+01 3.98e+01 3.63e+01
#  69700. -8420.j 70200. -8870.j 70700. -9350.j 71400. -9690.j
#  72000.-10000.j 72500.-10400.j 73400.-10800.j 74100.-11000.j
#  74700.-11400.j 75400.-11800.j 76300.-12200.j 77100.-12500.j
#  77900.-12700.j 78800.-13100.j 79700.-13300.j 80900.-13700.j
#  81600.-13800.j 82500.-14100.j 83600.-14400.j]
# Shape of frequencies: (151,)
# Shape of Z: (151,)
# /usr/local/lib/python3.10/dist-packages/impedance/visualization.py:39: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string ".-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(np.real(Z), -np.imag(Z), fmt, **kwargs)
# /usr/local/lib/python3.10/dist-packages/impedance/visualization.py:39: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string ".-" (-> marker='.'). The keyword argument will take precedence.
#   ax.plot(np.real(Z), -np.imag(Z), fmt, **kwargs)
# Circuit string: R_0-p(R_1,CPE_1)-p(R_2,CPE_2)
# Fit: True
#
# Initial guesses:
#     R_0 = 3.29e+02 [Ohm]
#     R_1 = 6.54e+04 [Ohm]
#   CPE_1_0 = 5.47e-10 [Ohm^-1 sec^a]
#   CPE_1_1 = 9.26e-01 []
#     R_2 = 9.23e+04 [Ohm]
#   CPE_2_0 = 9.87e-06 [Ohm^-1 sec^a]
#   CPE_2_1 = 2.94e-01 []
#
# Fit parameters:
#     R_0 = 3.29e+02  (+/- 1.39e+03) [Ohm]
#     R_1 = 6.54e+04  (+/- 1.75e+02) [Ohm]
#   CPE_1_0 = 3.13e-10  (+/- 3.16e-10) [Ohm^-1 sec^a]
#   CPE_1_1 = 9.26e-01  (+/- 4.86e-03) []
#     R_2 = 9.23e+04  (+/- 5.79e+00) [Ohm]
#   CPE_2_0 = 2.02e-05  (+/- 3.10e-06) [Ohm^-1 sec^a]
#   CPE_2_1 = 3.00e-01  (+/- 4.63e-02) []
#
#      Re(Z)_fit   Img(Z)_fit
# 0   958.426218  1811.102828
# 1   993.773433  1958.756813
# 2  1032.136566  2118.422835
# 3  1074.022334  2291.670775
# 4  1120.165564  2480.843793
# Circuit Type 1
#
# Circuit string: R_0-p(R_1,CPE_1)-p(R_2,CPE_2)
# Fit: True
#
# Initial guesses:
#     R_0 = 3.29e+02 [Ohm]
#     R_1 = 6.54e+04 [Ohm]
#   CPE_1_0 = 5.47e-10 [Ohm^-1 sec^a]
#   CPE_1_1 = 9.26e-01 []
#     R_2 = 9.23e+04 [Ohm]
#   CPE_2_0 = 9.87e-06 [Ohm^-1 sec^a]
#   CPE_2_1 = 2.94e-01 []
#
# Fit parameters:
#     R_0 = 3.29e+02  (+/- 1.39e+03) [Ohm]
#     R_1 = 6.54e+04  (+/- 1.75e+02) [Ohm]
#   CPE_1_0 = 3.13e-10  (+/- 3.16e-10) [Ohm^-1 sec^a]
#   CPE_1_1 = 9.26e-01  (+/- 4.86e-03) []
#     R_2 = 9.23e+04  (+/- 5.79e+00) [Ohm]
#   CPE_2_0 = 2.02e-05  (+/- 3.10e-06) [Ohm^-1 sec^a]
#   CPE_2_1 = 3.00e-01  (+/- 4.63e-02) []
